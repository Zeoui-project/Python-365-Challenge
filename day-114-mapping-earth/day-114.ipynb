# %% [markdown]
# # Mapping Earth using Python

# %%
# %pip install trame
# Out:
# ...
#
# ...
#                                               0.0/225.7 kB ? eta -:--:--
#      -------------------------------------- 225.7/225.7 kB 6.7 MB/s eta 0:00:00
# ...
#                                               0.0/320.6 kB ? eta -:--:--
#      -------------------------------------- 320.6/320.6 kB 9.7 MB/s eta 0:00:00
# ...
#                                               0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
#                                               0.0/60.2 kB ? eta -:--:--
#      ---------------------------------------- 60.2/60.2 kB ? eta 0:00:00
# ...
#                                               0.0/44.9 kB ? eta -:--:--
#      ---------------------------------------- 44.9/44.9 kB 2.2 MB/s eta 0:00:00
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# ...

# %%
# %pip install pyvista
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyvista

sphere = pyvista.Sphere()
sphere.plot(show_edges=True)
# Out:
# c:\Users\Vel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyvista\jupyter\notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame.ui.vuetify'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
from pyvista import examples

dataset = examples.load_globe()
texture = examples.load_globe_texture()
dataset.plot(texture=texture)
# Out:
# c:\Users\Vel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyvista\jupyter\notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame.ui.vuetify'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
