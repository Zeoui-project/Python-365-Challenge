# %% [markdown]
# # Image Watermarking using Python

# %%
from PIL import Image, ImageDraw, ImageFont
img = Image.open(r'photo.jpg')
draw = ImageDraw.Draw(img)
text = "zeoui-project"
font = ImageFont.truetype('arial.ttf', 50)
textwidth, textheight = draw.textsize(text, font)
width, height = img.size
x = width/2-textwidth/2
y = height-textheight-150
draw.text((x,y), text, font=font)
img.save(r'wmPhoto.png')
Image.open('wmPhoto.png')
# Out:
# C:\Users\Vel\AppData\Local\Temp\ipykernel_19196\2465735689.py:6: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   textwidth, textheight = draw.textsize(text, font)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=897x897>
