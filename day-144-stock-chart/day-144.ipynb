# %% [markdown]
# # Stock Chart plot using Python

# %%
# %pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.22-py2.py3-none-any.whl (63 kB)
#                                               0.0/63.2 kB ? eta -:--:--
#      ------                                   10.2/63.2 kB ? eta -:--:--
#      ------------------                     30.7/63.2 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 63.2/63.2 kB 840.3 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (1.25.0)
# Requirement already satisfied: requests>=2.26 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.28.2)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Using cached lxml-4.9.2-cp311-cp311-win_amd64.whl (3.8 MB)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pytz>=2022.5 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2023.3)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.3.8-py311-none-any.whl (14 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.11.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in c:\users\vel\appdata\roaming\python\python311\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Collecting webencodings (from html5lib>=1.1->yfinance)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vel\appdata\roaming\python\python311\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26->yfinance) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Installing collected packages: webencodings, multitasking, appdirs, lxml, html5lib, frozendict, yfinance
# Successfully installed appdirs-1.4.4 frozendict-2.3.8 html5lib-1.1 lxml-4.9.2 multitasking-0.0.11 webencodings-0.5.1 yfinance-0.2.22
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Download historical data of STOCK.NS
ticker = input("Enter Stock Name : ")
data = yf.download(ticker, start="2021-01-01", end="2023-03-03")

# Plot the stock chart
plt.figure(figsize=(10, 5))
plt.plot(data["Close"])
plt.title(f"{ticker} Stock Chart")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
