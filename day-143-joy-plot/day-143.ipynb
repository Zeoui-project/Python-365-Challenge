# %% [markdown]
# # Joy Plot Graph using Python

# %%
# %pip install joypy
# Out:
# Collecting joypy
#   Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from joypy) (1.25.0)
# Collecting scipy>=0.11.0 (from joypy)
#   Downloading scipy-1.11.1-cp311-cp311-win_amd64.whl (44.0 MB)
#                                               0.0/44.0 MB ? eta -:--:--
#                                               0.3/44.0 MB 6.5 MB/s eta 0:00:07
#      -                                        1.5/44.0 MB 19.2 MB/s eta 0:00:03
#      --                                       3.0/44.0 MB 23.7 MB/s eta 0:00:02
#      ----                                     4.5/44.0 MB 26.1 MB/s eta 0:00:02
#      -----                                    6.3/44.0 MB 28.8 MB/s eta 0:00:02
#      -------                                  7.7/44.0 MB 29.2 MB/s eta 0:00:02
#      ---------                                9.9/44.0 MB 31.8 MB/s eta 0:00:02
#      ----------                              11.7/44.0 MB 36.4 MB/s eta 0:00:01
#      ------------                            13.9/44.0 MB 38.5 MB/s eta 0:00:01
#      -------------                           15.7/44.0 MB 43.7 MB/s eta 0:00:01
#      ---------------                         17.7/44.0 MB 43.7 MB/s eta 0:00:01
#      -----------------                       19.7/44.0 MB 43.7 MB/s eta 0:00:01
#      -------------------                     21.9/44.0 MB 46.7 MB/s eta 0:00:01
#      ---------------------                   23.9/44.0 MB 43.5 MB/s eta 0:00:01
#      -----------------------                 26.2/44.0 MB 46.7 MB/s eta 0:00:01
#      ------------------------                27.9/44.0 MB 43.5 MB/s eta 0:00:01
#      --------------------------              30.0/44.0 MB 46.9 MB/s eta 0:00:01
#      ----------------------------            31.9/44.0 MB 46.7 MB/s eta 0:00:01
#      ------------------------------          33.8/44.0 MB 43.7 MB/s eta 0:00:01
#      --------------------------------        36.1/44.0 MB 46.9 MB/s eta 0:00:01
#      ---------------------------------       38.0/44.0 MB 43.7 MB/s eta 0:00:01
#      -----------------------------------     40.3/44.0 MB 46.7 MB/s eta 0:00:01
#      -------------------------------------   42.2/44.0 MB 46.7 MB/s eta 0:00:01
#      --------------------------------------  43.4/44.0 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------  44.0/44.0 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------  44.0/44.0 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------  44.0/44.0 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------- 44.0/44.0 MB 24.3 MB/s eta 0:00:00
# Collecting pandas>=0.20.0 (from joypy)
#   Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
#                                               0.0/10.6 MB ? eta -:--:--
#      --------                                 2.1/10.6 MB 68.7 MB/s eta 0:00:01
#      --------------                           3.7/10.6 MB 47.8 MB/s eta 0:00:01
#      --------------------                     5.5/10.6 MB 43.8 MB/s eta 0:00:01
#      ------------------------------           8.0/10.6 MB 46.4 MB/s eta 0:00:01
#      ------------------------------------     9.8/10.6 MB 44.6 MB/s eta 0:00:01
#      --------------------------------------  10.6/10.6 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------- 10.6/10.6 MB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from joypy) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vel\appdata\roaming\python\python311\site-packages (from pandas>=0.20.0->joypy) (2.8.2)
# Collecting pytz>=2020.1 (from pandas>=0.20.0->joypy)
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#                                               0.0/502.3 kB ? eta -:--:--
#      ------------------------------------- 502.3/502.3 kB 32.8 MB/s eta 0:00:00
# Collecting tzdata>=2022.1 (from pandas>=0.20.0->joypy)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#                                               0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->joypy) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->joypy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->joypy) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->joypy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vel\appdata\roaming\python\python311\site-packages (from matplotlib->joypy) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->joypy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vel\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->joypy) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\vel\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->joypy) (1.16.0)
# Installing collected packages: pytz, tzdata, scipy, pandas, joypy
# Successfully installed joypy-0.2.6 pandas-2.0.3 pytz-2023.3 scipy-1.11.1 tzdata-2023.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import joypy
import pandas as pd
from matplotlib import pyplot as plt

# Create a dataset of random numbers
data = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [6, 7, 8, 9, 10]})

# Create the joy plot
fig, axes = joypy.joyplot(data, ylim='own')

# Add labels and title
plt.xlabel("Value")
plt.ylabel("Variable")
plt.title("Joy Plot of two Variables")

# Show Figure
plt.show()
