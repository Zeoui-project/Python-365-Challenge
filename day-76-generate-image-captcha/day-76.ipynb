# %% [markdown]
# # Generate Image Captcha using Python

# %%
# %pip install captcha
# Out:
# Collecting captcha
#   Downloading captcha-0.4-py3-none-any.whl (102 kB)
#      -------------------------------------- 102.5/102.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in f:\file penting\semester 5 binus aso\data science and application (pak zacky)\praktikum\praktikum\.venv\lib\site-packages (from captcha) (9.4.0)
# Installing collected packages: captcha
# Successfully installed captcha-0.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from captcha.image import ImageCaptcha
# Specify the image size
image = ImageCaptcha(width = 300, height = 100)
# Specify the text to be displayed
captcha_text = input("Enter Captcha text :")
# Generate the image of the given text
data = image.generate(captcha_text)
# Write the image on the given file and save it
image.write(captcha_text, 'E:\Python\Project-365-Challenge\day-76-generate-image-captcha\CAPTCHA.png')
from PIL import Image
Image.open('E:\Python\Project-365-Challenge\day-76-generate-image-captcha\CAPTCHA.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x100>
